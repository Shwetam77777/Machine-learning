# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"F:\Python & Machine Learning\melbourne.csv")
df=pd.DataFrame(dataset)
df
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  23547.000000  1.839600e+04  23546.000000  23546.000000  19066.000000
# mean       2.976048  1.056697e+06     10.306515   3109.782893      2.951956
# std        0.974501  6.419217e+05      6.016318     94.522190      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.200000   3047.000000      2.000000
# 50%        3.000000  8.800000e+05      9.500000   3101.000000      3.000000
# 75%        4.000000  1.302000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  19063.000000  18921.000000   17410.000000  10018.000000  11540.000000
# mean       1.570897      1.626235     551.783458    154.527895   1964.636742
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
# Suburb           23547 non-null object
# Address          23547 non-null object
# Rooms            23547 non-null int64
# Type             23547 non-null object
# Price            18396 non-null float64
# Method           23547 non-null object
# SellerG          23547 non-null object
# Date             23547 non-null object
# Distance         23546 non-null float64
# Postcode         23546 non-null float64
# Bedroom2         19066 non-null float64
# Bathroom         19063 non-null float64
# Car              18921 non-null float64
# Landsize         17410 non-null float64
# BuildingArea     10018 non-null float64
# YearBuilt        11540 non-null float64
# CouncilArea      15656 non-null object
# Lattitude        19243 non-null float64
# Longtitude       19243 non-null float64
# Regionname       23546 non-null object
# Propertycount    23546 non-null float64
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
# 5        2
# 6        0
# 7        1
# 8        2
# 9        2
# 10       2
# 11       0
# 12       1
# 13       1
# 14       0
# 15       9
# 16       9
# 17       2
# 18       0
# 19       9
# 20       1
# 21       9
# 22       9
# 23       2
# 24       0
# 25       0
# 26       7
# 27       9
# 28       2
# 29       2
#         ..
# 23517    2
# 23518    3
# 23519    3
# 23520    2
# 23521    1
# 23522    4
# 23523    3
# 23524    3
# 23525    1
# 23526    2
# 23527    1
# 23528    5
# 23529    4
# 23530    5
# 23531    9
# 23532    1
# 23533    5
# 23534    2
# 23535    3
# 23536    4
# 23537    2
# 23538    1
# 23539    2
# 23540    2
# 23541    1
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %%
df[df["BuildingArea"].isnull()]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 0             Abbotsford        68 Studley St      2    h        NaN     SS
# 1             Abbotsford         85 Turner St      2    h  1480000.0      S
# 3             Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 5             Abbotsford     40 Federation La      3    h   850000.0     PI
# 8             Abbotsford         53 Turner St      2    h        NaN      S
# 9             Abbotsford         99 Turner St      2    h        NaN      S
# 10            Abbotsford       129 Charles St      2    h   941000.0      S
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 17            Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# ...

# %%
df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.isnull().any(axis=1)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14       False
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 23517     True
# 23518     True
# 23519     True
# 23520     True
# 23521     True
# 23522     True
# 23523     True
# 23524     True
# 23525     True
# 23526     True
# 23527     True
# 23528     True
# 23529     True
# 23530     True
# 23531     True
# 23532     True
# 23533     True
# 23534     True
# 23535     True
# 23536     True
# 23537     True
# 23538     True
# 23539     True
# 23540     True
# 23541     True
# 23542     True
# 23543     True
# ...

# %%
round(100*(df.isnull().sum())/len(df.index),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df.drop(labels=['BuildingArea'],axis=1,inplace=True)

# %%
df.drop(labels=['YearBuilt'],axis=1,inplace=True)

# %%
df.drop(labels=['CouncilArea'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            5151
# Method              0
# SellerG             0
# Date                0
# Distance            1
# Postcode            1
# Bedroom2         4481
# Bathroom         4484
# Car              4626
# Landsize         6137
# Lattitude        4304
# Longtitude       4304
# Regionname          1
# Propertycount       1
# dtype: int64

# %%
round(100*(df.isnull().sum())/len(df.index),5)
# Out:
# Suburb            0.00000
# Address           0.00000
# Rooms             0.00000
# Type              0.00000
# Price            21.87540
# Method            0.00000
# SellerG           0.00000
# Date              0.00000
# Distance          0.00425
# Postcode          0.00425
# Bedroom2         19.03003
# Bathroom         19.04277
# Car              19.64581
# Landsize         26.06277
# Lattitude        18.27834
# Longtitude       18.27834
# Regionname        0.00425
# Propertycount     0.00425
# dtype: float64

# %%
df[df.isnull().sum(axis=1)>=5]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# 27            Abbotsford    13/84 Trenerry Cr      1    u   500000.0      S
# 33            Abbotsford     250 Langridge St      2    t   847000.0      S
# 34            Abbotsford      16b Mollison St      2    h        NaN     PI
# 45            Abbotsford    65/80 Trenerry Cr      1    u   480000.0      S
# 46            Abbotsford  119/52 Nicholson St      1    u   423500.0      S
# 47            Abbotsford           8b Park St      4    h        NaN     PI
# ...

# %%
df=df[df.isnull().sum(axis=1)<5]
df
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
round(100*(df.isnull().sum())/len(df.index),5)
# Out:
# Suburb            0.00000
# Address           0.00000
# Rooms             0.00000
# Type              0.00000
# Price            21.53334
# Method            0.00000
# SellerG           0.00000
# Date              0.00000
# Distance          0.00000
# Postcode          0.00000
# Bedroom2          0.83221
# Bathroom          0.84781
# Car               1.58639
# Landsize          9.44554
# Lattitude         0.13523
# Longtitude        0.13523
# Regionname        0.00000
# Propertycount     0.00000
# dtype: float64

# %%
df=df[df['Price'].notnull()]
df
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14         Abbotsford        98 Charles St      2    h  1636000.0      S
# 17         Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 18         Abbotsford        10 Valiant St      2    h  1097000.0      S
# 23         Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 24         Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# ...

# %%
round(100*(df.isnull().sum())/len(df.index),5)
# Out:
# Suburb           0.00000
# Address          0.00000
# Rooms            0.00000
# Type             0.00000
# Price            0.00000
# Method           0.00000
# SellerG          0.00000
# Date             0.00000
# Distance         0.00000
# Postcode         0.00000
# Bedroom2         1.05396
# Bathroom         1.06721
# Car              1.76322
# Landsize         9.83031
# Lattitude        0.14583
# Longtitude       0.14583
# Regionname       0.00000
# Propertycount    0.00000
# dtype: float64

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  15086.000000  1.508600e+04  15086.000000  15086.000000  14927.000000
# mean       2.932653  1.066695e+06     10.290753   3107.384330      2.913043
# std        0.963214  6.389331e+05      6.070538     94.360707      0.964641
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.400000e+05      6.100000   3046.000000      2.000000
# 50%        3.000000  9.000000e+05      9.300000   3087.000000      3.000000
# 75%        3.000000  1.320000e+06     13.100000   3149.750000      3.000000
# max       12.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  14925.000000  14820.000000   13603.000000  15064.000000  15064.000000
# mean       1.538492      1.615520     558.116371    -37.809849    144.996338
# ...

# %%
df['Lattitude'].fillna(df['Lattitude'].mean(),inplace=True)
df['Longtitude'].fillna(df['Longtitude'].mean(),inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
round(100*(df.isnull().sum())/len(df.index),5)
# Out:
# Suburb           0.00000
# Address          0.00000
# Rooms            0.00000
# Type             0.00000
# Price            0.00000
# Method           0.00000
# SellerG          0.00000
# Date             0.00000
# Distance         0.00000
# Postcode         0.00000
# Bedroom2         1.05396
# Bathroom         1.06721
# Car              1.76322
# Landsize         9.83031
# Lattitude        0.00000
# Longtitude       0.00000
# Regionname       0.00000
# Propertycount    0.00000
# dtype: float64

# %%
df['Bathroom'].value_counts()
# Out:
# 1.0    8193
# 2.0    5532
# 3.0    1013
# 4.0     114
# 0.0      34
# 5.0      30
# 6.0       5
# 8.0       2
# 7.0       2
# Name: Bathroom, dtype: int64

# %%
df['Bathroom'].fillna(1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['Car'].value_counts()
# Out:
# 2.0     6183
# 1.0     6072
# 0.0     1057
# 3.0      809
# 4.0      549
# 5.0       66
# 6.0       60
# 8.0       12
# 7.0        8
# 10.0       3
# 9.0        1
# Name: Car, dtype: int64

# %%
df['Car'].fillna(2.0,inplace=True)

# %%
df['Bedroom2'].value_counts()
# Out:
# 3.0     6463
# 2.0     4124
# 4.0     2864
# 1.0      763
# 5.0      604
# 6.0       71
# 0.0       16
# 7.0       12
# 8.0        5
# 9.0        3
# 10.0       1
# 20.0       1
# Name: Bedroom2, dtype: int64

# %%
df['Bedroom2'].fillna(3.0,inplace=True)

# %%
round(100*(df.isnull().sum())/len(df.index),5)
# Out:
# Suburb           0.00000
# Address          0.00000
# Rooms            0.00000
# Type             0.00000
# Price            0.00000
# Method           0.00000
# SellerG          0.00000
# Date             0.00000
# Distance         0.00000
# Postcode         0.00000
# Bedroom2         0.00000
# Bathroom         0.00000
# Car              0.00000
# Landsize         9.83031
# Lattitude        0.00000
# Longtitude       0.00000
# Regionname       0.00000
# Propertycount    0.00000
# dtype: float64

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  15086.000000  1.508600e+04  15086.000000  15086.000000  15086.000000
# mean       2.932653  1.066695e+06     10.290753   3107.384330      2.913960
# std        0.963214  6.389331e+05      6.070538     94.360707      0.959585
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.400000e+05      6.100000   3046.000000      2.000000
# 50%        3.000000  9.000000e+05      9.300000   3087.000000      3.000000
# 75%        3.000000  1.320000e+06     13.100000   3149.750000      3.000000
# max       12.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  15086.000000  15086.000000   13603.000000  15086.000000  15086.000000
# mean       1.532746      1.622299     558.116371    -37.809849    144.996338
# ...
